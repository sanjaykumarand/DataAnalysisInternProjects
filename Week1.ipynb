# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjaykumarand/Projects/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("n.csv")
df.shape
df.dtypes
df.head()
# Out:
#   show_id     type               title           director  \
# 0  s10000    Movie  Netflix Original 0  Christopher Nolan
# 1  s10001  TV Show  Netflix Original 1       Ava DuVernay
# 2  s10002    Movie  Netflix Original 2       Greta Gerwig
# 3  s10003    Movie  Netflix Original 3       Ava DuVernay
# 4  s10004    Movie  Netflix Original 4  Christopher Nolan
#
#                               cast         country        date_added  \
# 0  Leonardo DiCaprio, Kate Winslet     South Korea  January 01, 2015
# 1                              NaN  United Kingdom  January 06, 2015
# 2         Emma Stone, Ryan Gosling   United States  January 11, 2015
# 3  Chris Evans, Scarlett Johansson   United States  January 16, 2015
# 4  Leonardo DiCaprio, Kate Winslet             NaN  January 21, 2015
#
#    release_year rating duration                     listed_in  \
# 0          2001      R   87 min      Children & Family Movies
# 1          1999    NaN  129 min                 Documentaries
# ...

# %%
Drop=df.drop(columns=['cast','director','description'])
print("Dropped Columns:\n",Drop)
# Out:
# Dropped Columns:
#      show_id     type                 title         country        date_added  \
# 0    s10000    Movie    Netflix Original 0     South Korea  January 01, 2015
# 1    s10001  TV Show    Netflix Original 1  United Kingdom  January 06, 2015
# 2    s10002    Movie    Netflix Original 2   United States  January 11, 2015
# 3    s10003    Movie    Netflix Original 3   United States  January 16, 2015
# 4    s10004    Movie    Netflix Original 4             NaN  January 21, 2015
# ..      ...      ...                   ...             ...               ...
# 495  s10495    Movie  Netflix Original 495  United Kingdom  October 11, 2021
# 496  s10496    Movie  Netflix Original 496             NaN  October 16, 2021
# 497  s10497  TV Show  Netflix Original 497           India  October 21, 2021
# 498  s10498    Movie  Netflix Original 498     South Korea  October 26, 2021
# 499  s10499      NaN  Netflix Original 499   United States  October 31, 2021
#
# ...

# %%
df.dropna()
# Out:
#     show_id     type                 title           director  \
# 0    s10000    Movie    Netflix Original 0  Christopher Nolan
# 2    s10002    Movie    Netflix Original 2       Greta Gerwig
# 3    s10003    Movie    Netflix Original 3       Ava DuVernay
# 7    s10007    Movie    Netflix Original 7       Bong Joon-ho
# 12   s10012    Movie   Netflix Original 12   Steven Spielberg
# ..      ...      ...                   ...                ...
# 487  s10487  TV Show  Netflix Original 487       Greta Gerwig
# 489  s10489    Movie  Netflix Original 489       Ava DuVernay
# 491  s10491    Movie  Netflix Original 491       Ava DuVernay
# 495  s10495    Movie  Netflix Original 495       Greta Gerwig
# 497  s10497  TV Show  Netflix Original 497        Zoya Akhtar
#
#                                 cast         country          date_added  \
# 0    Leonardo DiCaprio, Kate Winslet     South Korea    January 01, 2015
# ...

# %%
df.drop_duplicates()
# Out:
#     show_id     type                 title           director  \
# 0    s10000    Movie    Netflix Original 0  Christopher Nolan
# 1    s10001  TV Show    Netflix Original 1       Ava DuVernay
# 2    s10002    Movie    Netflix Original 2       Greta Gerwig
# 3    s10003    Movie    Netflix Original 3       Ava DuVernay
# 4    s10004    Movie    Netflix Original 4  Christopher Nolan
# ..      ...      ...                   ...                ...
# 495  s10495    Movie  Netflix Original 495       Greta Gerwig
# 496  s10496    Movie  Netflix Original 496       Ava DuVernay
# 497  s10497  TV Show  Netflix Original 497        Zoya Akhtar
# 498  s10498    Movie  Netflix Original 498                NaN
# 499  s10499      NaN  Netflix Original 499       Bong Joon-ho
#
#                                 cast         country        date_added  \
# 0    Leonardo DiCaprio, Kate Winslet     South Korea  January 01, 2015
# 1                                NaN  United Kingdom  January 06, 2015
# ...

# %%
df['release_year'].astype(int)
# Out:
# 0      2001
# 1      1999
# 2      1995
# 3      2007
# 4      2015
#        ...
# 495    2013
# 496    2013
# 497    2019
# 498    2015
# 499    2006
# Name: release_year, Length: 500, dtype: int64

# %%
main_genre = df['show_id']
print("Extracted Column:\n",main_genre)
# Out:
# Extracted Column:
#  0      s10000
# 1      s10001
# 2      s10002
# 3      s10003
# 4      s10004
#         ...
# 495    s10495
# 496    s10496
# 497    s10497
# 498    s10498
# 499    s10499
# Name: show_id, Length: 500, dtype: object

# %%
df.shape
# Out:
# (500, 12)

# %%
import seaborn as sns
sns.countplot(x='type', data=df)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
sns.countplot(x='rating', data=df, order=df['rating'].value_counts().index)
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
main_genre.value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='show_id'>

# %%
df['release_year'].value_counts().sort_index().plot(kind='line')
# Out:
# <Axes: xlabel='release_year'>

# %%
df['country'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='country'>

# %%
movie_df = df[df['type'] == 'Movie']
movie_df['duration_min'] = movie_df['duration'].str.extract('(\d+)').astype(float)
sns.histplot(movie_df['duration_min'], bins=30, kde=True)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-867025646.py:2: SyntaxWarning: invalid escape sequence '\d'
#   movie_df['duration_min'] = movie_df['duration'].str.extract('(\d+)').astype(float)
# /tmp/ipython-input-867025646.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_df['duration_min'] = movie_df['duration'].str.extract('(\d+)').astype(float)
# <Axes: xlabel='duration_min', ylabel='Count'>

# %%
tv_df = df[df['type'] == 'TV Show'].copy()
tv_df['season_count'] = tv_df['duration'].str.extract('(\d+)')[0].fillna(0).astype(int)
tv_df['season_group'] = tv_df['season_count'].apply(lambda x: str(x) if x <= 10 else '10+')
sns.countplot(x='season_group', data=tv_df, palette='pastel')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-584744735.py:2: SyntaxWarning: invalid escape sequence '\d'
#   tv_df['season_count'] = tv_df['duration'].str.extract('(\d+)')[0].fillna(0).astype(int)
# /tmp/ipython-input-584744735.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='season_group', data=tv_df, palette='pastel')
# <Axes: xlabel='season_group', ylabel='count'>
